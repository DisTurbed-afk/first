# %% [markdown]
# <a href="https://colab.research.google.com/github/DisTurbed-afk/first/blob/master/TorrentUpload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install transmission-cli
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libevent-2.1-6 libminiupnpc10 libnatpmp1 transmission-common
# Suggested packages:
#   minissdpd natpmpc transmission-daemon transmission-gtk
# The following NEW packages will be installed:
#   libevent-2.1-6 libminiupnpc10 libnatpmp1 transmission-cli
#   transmission-common
# 0 upgraded, 5 newly installed, 0 to remove and 11 not upgraded.
# Need to get 808 kB of archives.
# After this operation, 3,975 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libevent-2.1-6 amd64 2.1.8-stable-4build1 [133 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libminiupnpc10 amd64 1.9.20140610-4ubuntu2 [24.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnatpmp1 amd64 20150609-2 [7,612 B]
# ...

# %%
# !transmission-cli -w '/content/drive/My Drive' "/content/kali-linux-2020.3-installer-amd64.iso.torrent"
# Out:
# transmission-cli 2.92 (14714)
# [2020-09-16 11:57:42.542] Transmission 2.92 (14714) started
# [2020-09-16 11:57:42.543] RPC Server: Adding address to whitelist: 127.0.0.1
# [2020-09-16 11:57:42.543] UDP: Failed to set receive buffer: requested 4194304, got 425984
# [2020-09-16 11:57:42.543] UDP: Please add the line "net.core.rmem_max = 4194304" to /etc/sysctl.conf
# [2020-09-16 11:57:42.543] UDP: Failed to set send buffer: requested 1048576, got 425984
# [2020-09-16 11:57:42.543] UDP: Please add the line "net.core.wmem_max = 1048576" to /etc/sysctl.conf
# [2020-09-16 11:57:42.543] DHT: Generating new id
# [2020-09-16 11:57:42.594] Saved "/root/.config/transmission/torrents/kali-linux-2020-3-installer-amd64-iso.ab96176eac05d49d.torrent"
# [2020-09-16 11:57:42.594] kali-linux-2020-3-installer-amd64-iso: Queued for verification
# [2020-09-16 11:57:42.594] kali-linux-2020-3-installer-amd64-iso: Verifying torrent
# ...
